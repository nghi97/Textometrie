# %%
import pandas as pd

# %%
texto=pd.read_csv('C://Users//User//Desktop//Textometrie.csv',index_col=0)

# %%
texto.head()
# Out:
#        CULTURE  INNOVATION & TECHNOLOGIE    VIOLENCE & CONFLIT   \
# notre        3                          3                    12
# monde        4                          3                     4
# est         11                          9                     4
# riche        1                          0                     0
# de          59                         45                    39
#
#         ENVIRONNEMENT
# notre                0
# monde                0
# est                  6
# riche                0
# de                  37

# %%
texto['Total']=texto.sum(axis=1)

# %%
texto.head()
# Out:
#        CULTURE  INNOVATION & TECHNOLOGIE    VIOLENCE & CONFLIT   \
# notre        3                          3                    12
# monde        4                          3                     4
# est         11                          9                     4
# riche        1                          0                     0
# de          59                         45                    39
#
#         ENVIRONNEMENT   Total
# notre                0     18
# monde                0     11
# est                  6     30
# riche                0      1
# de                  37    180

# %%
texto=texto.sort_values(by='Total',ascending=False)

# %%
texto.to_csv('Textometrie.csv')

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.tokenize import sent_tokenize
import re

# %%
texto.head(20)
# Out:
#       CULTURE  INNOVATION & TECHNOLOGIE    VIOLENCE & CONFLIT   \
# de         59                         45                    39
# la         46                         23                    23
# et         32                         19                    24
# les        27                         21                    28
# des        31                         23                    18
# à          33                         23                     5
# le         31                          8                    15
# en         17                         11                     8
# un         20                         12                    14
# pour       16                          6                    14
# que         9                          7                    13
# nous        1                          4                    32
# une        11                         12                     9
# qui        11                          6                     4
# ...

# %%
french_stopwords = set(stopwords.words('french'))
filtre_stopfr =  lambda liste: [token for token in liste if token not in french_stopwords]

# %%
listmot=texto.index.to_list()
listmot
# Out:
# ['de',
#  'la',
#  'et',
#  'les',
#  'des',
#  'à',
#  'le',
#  'en',
#  'un',
#  'pour',
#  'que',
#  'nous',
#  'une',
#  'qui',
#  'est',
#  'l',
#  'du',
#  'a',
#  'plus',
#  'sur',
#  'ou',
#  'sont',
#  'dans',
#  'vous',
#  'avec',
#  'comme',
#  'notre',
#  'pas',
#  'jeunes',
#  'l’eau',
#  'ne',
#  'avons',
#  'pays',
#  'vie',
#  'au',
#  'ce',
#  'par',
#  'canada',
#  'c’est',
#  'il',
#  'aux',
#  'd',
#  'se',
#  'être',
#  'leur',
#  'aussi',
#  'peut',
#  'monde',
#  'cela',
#  'tout',
#  'mais',
#  'cette',
#  'violence',
#  'internet',
#  'sociaux',
#  'souvent',
#  'ces',
#  'on',
#  'soit',
#  'social',
#  'théâtre',
#  'je',
#  'autres',
#  'niveau',
#  'leurs',
#  '«',
#  '»',
#  'fait',
#  'quand',
#  'femmes',
#  'sans',
#  'réseaux',
#  'si',
#  '-',
#  'faire',
#  'nos',
#  'aujourd’hui',
#  'ont',
#  'filles',
#  'charte',
#  'car',
#  'démocratie',
#  'face',
#  'cours',
#  'population',
#  'bien',
#  'qu’il',
#  'grand',
#  'société',
#  'y',
# ...

# %%
d=' '.join(listmot)
nvmmot=filtre_stopfr( word_tokenize(d, language="french") )

# %%
nvmmot=filtre_stopfr( word_tokenize(d, language="french") )
nvmmot=' '.join(nvmmot)
nvmmot = re.sub(r"[.:' ;,?=!\n]+()-«»’"," ",nvmmot)
nvmmot=nvmmot.split(" ")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-45d5a321e486> in <module>
#       1 nvmmot=filtre_stopfr( word_tokenize(d, language="french") )
# ----> 2 nvmmot.to_csv('mots.csv')
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
mots=[]
for i in nvmmot:
    if i not in ["’" , "-", "»", "«","%" ,")","(",'66','1','58','5','1758',
                 '000','2','809','4ème','40','36','82','a']:
        mots.append(i)
mots
# Out:
# ['plus',
#  'comme',
#  'jeunes',
#  'eau',
#  'pays',
#  'vie',
#  'canada',
#  'être',
#  'aussi',
#  'peut',
#  'monde',
#  'cela',
#  'tout',
#  'cette',
#  'violence',
#  'internet',
#  'sociaux',
#  'souvent',
#  'social',
#  'théâtre',
#  'autres',
#  'niveau',
#  'leurs',
#  'fait',
#  'quand',
#  'femmes',
#  'sans',
#  'réseaux',
#  'si',
#  'faire',
#  'aujourd',
#  'hui',
#  'filles',
#  'charte',
#  'car',
#  'démocratie',
#  'face',
#  'cours',
#  'population',
#  'bien',
#  'grand',
#  'société',
#  'technologique',
#  'victimes',
#  'très',
#  'toutes',
#  'libertés',
#  'neige',
#  '2015',
#  'contre',
#  'coutumes',
#  'créer',
#  'bon',
#  'première',
#  'groupes',
#  'partie',
#  'droits',
#  'effet',
#  'mondiale',
#  'entre',
#  'violences',
#  'nouveaux',
#  'personnes',
#  'nord',
#  'peuvent',
#  'parfois',
#  'beaucoup',
#  'encore',
#  'ans',
#  'différentes',
#  'impact',
#  'chaque',
#  'voir',
#  'autochtones',
#  'façon',
#  'peu',
#  'développement',
# ...

# %%
texto2=texto[texto.index.isin(mots)]

# %%
texto2.to_csv('Textofinale.csv')

# %%
texto2.head(20)
# Out:
#           CULTURE  INNOVATION & TECHNOLOGIE    VIOLENCE & CONFLIT   \
# plus            7                          9                     5
# comme           7                          3                     6
# jeunes          4                          4                     8
# pays           13                          1                     0
# vie             2                          6                     1
# canada         13                          0                     0
# être            2                          2                     8
# aussi           6                          1                     4
# peut            0                          4                     7
# monde           4                          3                     4
# cela            0                          5                     2
# tout            2                          6                     2
# cette           2                          4                     1
# ...

# %%
texto2.columns
# Out:
# Index(['CULTURE', 'INNOVATION & TECHNOLOGIE ', ' VIOLENCE & CONFLIT ',
#        ' ENVIRONNEMENT ', 'Total'],
#       dtype='object')

# %%
texto2.sort_values(by=' ENVIRONNEMENT ',ascending=False)
# Out:
#              CULTURE  INNOVATION & TECHNOLOGIE    VIOLENCE & CONFLIT   \
# vie                2                          6                     1
# plus               7                          9                     5
# si                 1                          1                     0
# cela               0                          5                     2
# mars               0                          0                     0
# ...              ...                        ...                   ...
# façon              1                          2                     1
# autochtones        4                          0                     0
# différentes        2                          1                     1
# ans                3                          1                     0
# travailler         0                          0                     1
#
#               ENVIRONNEMENT   Total
# vie                        5     14
# plus                       4     25
# ...
